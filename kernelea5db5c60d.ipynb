# %%
v1<-1
v2<-"Name"
v3<-TRUE
v4<-222L
v<-'C'

# %%
vec<-c(2,3,4,7,9)
print(mean(vec))
print(sort(vec,decreasing=TRUE))
data<-list(v1,v2,v3,v4,v)
names(data)<-c("element1","element2","element3","element4","element5")
print(data)
a<-array(c(1:18),dim=c(3,3,2))
print(a)

# %%
height <- c(132,151,162,139,166,147,122)
weight <- c(48,49,66,53,67,52,40)
gender <- c("male","male","female","female","male","female","male")

input_data <- data.frame(height,weight,gender)
print(input_data)

print(is.factor(input_data$gender))

print(input_data$gender)

# %%
data<-c(rep(c("M","M","M","M","M","F","T","M","B"),5,length=53))
f<-factor(data)
is.factor(f)
print(f)

# %%
m0<-matrix(c(1:20),nrow=5,ncol=4,byrow=TRUE)
m1<-matrix(c(1:20),nrow=5,ncol=4,byrow=FALSE)
res<-m0*m1
print(res)
